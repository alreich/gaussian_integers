# %% [markdown]
# # References

# %% [markdown]
# **"Octonion Quantum Chromodynamics"**, Chanyal, et al., Nov. 27, 2024. [https://arxiv.org/abs/1204.0242v1]

# %% [markdown]
# **"480 varieties of octonion multiplication"**, Dave Barber, Dec. 8, 2015. [http://tamivox.org/eugene/octonion480/index.html]
#
#     See Table 5 near the bottom of this webpage. It is the one produced by the method call, ``print_unit_mult_table(3)``.

# %% [markdown]
# **"The Gaussian Integers"**, Keith Conrad. [https://kconrad.math.uconn.edu/blurbs/ugradnumthy/Zinotes.pdf]
#
#     Many of the Zi algorithms and examples come from this paper.

# %% [markdown]
# **"The Octonions"**, John C. Baez, Dept. of Mathematics, Univ. of California, Riverside, May 16, 2001. [https://math.ucr.edu/home/baez/octonions/octonions.pdf]

# %% [markdown]
# **a list of papers on Octonions**, by Tevian Dray. [https://sites.science.oregonstate.edu/~tevian/cv/pubs.html#octonions]
