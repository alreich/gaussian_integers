# %% [markdown]
# # Gaussian Integers Modulo n

# %%
from mod_gaussians import *

# %%
Zni()
# Out:
# Zni(0)

# %%
a = Zni(3, 5)
b = Zni(5, 6)

# %%
print(f"{Zni.modulo_value() = }")
print(f"{a = }")
print(f"{b = }")
print(f"{a + b = }")
print(f"{a - b = }")
print(f"{a * b = }")
# Out:
# Zni.modulo_value() = 10
# a = Zni(3, 5)
# b = Zni(5, 6)
# a + b = Zni(8, 1)
# a - b = Zni(8, 9)
# a * b = Zni(5, 3)

# %%
print(f"{Zni.set_modulo_value(10) = }")
print(f"{a = }")
print(f"{b = }")
print(f"{a + b = }")
print(f"{a - b = }")
print(f"{a * b = }")
# Out:
# Zni.set_modulo_value(10) = 10
# a = Zni(3, 5)
# b = Zni(5, 6)
# a + b = Zni(8, 1)
# a - b = Zni(8, 9)
# a * b = Zni(5, 3)

# %%
(3 - 5) % 10
# Out:
# 8
